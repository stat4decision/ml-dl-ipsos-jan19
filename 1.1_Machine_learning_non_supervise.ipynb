# %% [markdown]
# # L’apprentissage non supervisé
#
# ## Implémentation d’une méthode de clustering avec Python
#
# Dans le cas d’un clustering les données consiste en un bloc de variables x
# desquelles on va extraire des groupes d’observations.
#
# Nous allons appliquer les k-means directement sur les données. Les k-means
# (k-moyennes) sont donc un algorithme d’apprentissage non supervisé permettant
# de construire des classes d’observations à partir d’un jeu de données de grande
# dimension.

# %% [markdown]
# ## Préparation des données
#
# Les données que nous utilisons sont des données sur les communes d’Île-de-
# France et leur caractéristiques socio-démographiques.
#
# Notre objectif est ici de comprendre s’il existe des classes de communes ayant des caractéristiques proches.
# On obtiendra ainsi une typologie des communes d’Île-de-France et on pourra représenter
# ces groupes sur une carte.
#
# Nous allons préparer ces données qui sont disponibles sur le site du livre. Une
# description est disponible au début du chapitre 4.m

# %%
import pandas as pd
import numpy as np
# on récupère le fichier csv
data=pd.read_csv("./data/base-dpt.csv",sep=";")
# on enlève des variables avec trop de données manquantes
data.drop(["PIMP14","TP6014"],axis=1,inplace=True)
# on enlève les observations avec des données manquantes
data.dropna(inplace=True)
# on extrait dans un DataFrame la position géographique des comunes
position=pd.DataFrame(data["geo_point_2d"])
# on crée une colonne longitude en prenant la première partie
# de la colonne geo_point_2
position["longitude"]=pd.to_numeric(position["geo_point_2d"].str.split(',')\
                                    .str.get(0))
# on fait la même chose pour la latitude
position["latitude"]=pd.to_numeric(position["geo_point_2d"].str.split(',')\
                                   .str.get(1))
# finalement, on sélectionne uniquement les données numériques
# pour faire notre K-means et on enlève trois variables inutiles
x=data.select_dtypes(np.number).drop(["CODGEO","REG","DEP"],axis=1)

# %%
data
# Out:
#       CODGEO                    LIBGEO  REG  DEP  P14_POP  P09_POP  SUPERF  \
# 0      95555             Saint-Gratien   11   95  20996.0  20258.0    2.42
# 1      95488                Pierrelaye   11   95   8155.0   7920.0    9.21
# 2      95543      Saint-Cyr-en-Arthies   11   95    242.0    229.0    3.89
# 3      95523            La Roche-Guyon   11   95    446.0    447.0    4.61
# 4      95678             Villiers-Adam   11   95    838.0    828.0    9.82
# 5      95627             Vallangoujard   11   95    636.0    638.0    7.60
# 7      95594                     Seugy   11   95   1008.0   1042.0    1.70
# 8      95676        Villers-en-Arthies   11   95    503.0    463.0    8.25
# 10     95026         Asnières-sur-Oise   11   95   2620.0   2530.0   14.07
# 11     94069             Saint-Maurice   11   94  14874.0  14439.0    1.43
# 12     95019                Arnouville   11   95  14297.0  13321.0    2.84
# 13     95101                Bray-et-Lû   11   95    975.0    971.0    3.71
# 14     94070                   Santeny   11   94   3644.0   3676.0    9.91
# 15     94059        Le Plessis-Trévise   11   94  19732.0  18876.0    4.32
# 16     95063                    Bezons   11   95  28431.0  28012.0    4.16
# 17     95120            Butry-sur-Oise   11   95   2250.0   1994.0    2.60
# 18     95051                 Beauchamp   11   95   8733.0   8777.0    3.02
# 19     95046                  Banthelu   11   95    145.0    122.0    8.10
# 20     78531           Rosny-sur-Seine   11   78   5842.0   5454.0   19.36
# 21     78440               Les Mureaux   11   78  31647.0  31490.0   11.99
# 22     78361           Mantes-la-Jolie   11   78  44985.0  43128.0    9.38
# 23     78368        Mareil-sur-Mauldre   11   78   1745.0   1736.0    4.33
# 24     78418                 Montesson   11   78  15126.0  15354.0    7.36
# 25     78524              Rocquencourt   11   78   3199.0   3247.0    2.78
# 26     78586              Sartrouville   11   78  51747.0  51459.0    8.46
# 27     78569              Sainte-Mesme   11   78    915.0    907.0    8.16
# 28     78513     La Queue-les-Yvelines   11   78   2183.0   2126.0    5.77
# 29     78565   Saint-Martin-des-Champs   11   78    318.0    324.0    6.21
# 30     78138     Chanteloup-les-Vignes   11   78  10204.0   9475.0    3.33
# 31     78217                     Épône   11   78   6474.0   6349.0   12.77
# ...      ...                       ...  ...  ...      ...      ...     ...
# 1268   91086                 Bondoufle   11   91   9132.0   9334.0    6.76
# 1269   91098            Boutervilliers   11   91    424.0    365.0    7.01
# 1270   91112                     Brouy   11   91    142.0    124.0    8.39
# 1271   91093         Boullay-les-Troux   11   91    625.0    657.0    4.80
# 1273   93039         L'Île-Saint-Denis   11   93   7293.0   7017.0    1.77
# 1274   92075                    Vanves   11   92  27783.0  26505.0    1.56
# 1275   93057   Les Pavillons-sous-Bois   11   93  23135.0  21226.0    2.92
# 1276   93074                  Vaujours   11   93   6867.0   6273.0    3.78
# 1277   93064           Rosny-sous-Bois   11   93  44448.0  40867.0    5.91
# 1278   93030                     Dugny   11   93  10420.0  10527.0    3.89
# 1279   92073                  Suresnes   11   92  48526.0  46053.0    3.79
# 1280   93061      Le Pré-Saint-Gervais   11   93  17554.0  18121.0    0.70
# 1281   95277                   Gonesse   11   95  26020.0  26361.0   20.09
# 1282   95116         Bruyères-sur-Oise   11   95   4157.0   3565.0    8.91
# 1283   95252              Franconville   11   95  34014.0  33276.0    6.19
# 1284   95203                  Eaubonne   11   95  24393.0  23878.0    4.42
# 1285   95150                   Chaussy   11   95    608.0    639.0   14.56
# 1286   95287         Grisy-les-Plâtres   11   95    632.0    598.0    7.15
# 1287   95154  Chennevières-lès-Louvres   11   95    317.0    338.0    4.58
# 1288   95254                Frémécourt   11   95    556.0    543.0    4.28
# 1289   95253              Frémainville   11   95    474.0    483.0    5.61
# 1291   95607                   Taverny   11   95  25875.0  26134.0   10.48
# 1292   95541      Saint-Clair-sur-Epte   11   95    981.0    909.0   12.18
# 1293   95641                    Vémars   11   95   2359.0   2208.0    8.18
# 1294   95554             Saint-Gervais   11   95    954.0    963.0   13.18
# 1295   95582                   Sannois   11   95  26826.0  25856.0    4.78
# 1296   95563        Saint-Leu-la-Forêt   11   95  15072.0  14783.0    5.24
# 1297   95682           Villiers-le-Sec   11   95    177.0    176.0    3.26
# 1298   95610              Théméricourt   11   95    278.0    259.0    7.58
# 1299   95675                  Villeron   11   95    758.0    728.0    5.61
#
#       NAIS0914  DECE0914       P14_MEN              ...               ETAZ15  \
# 0       1564.0     749.0   8909.817815              ...                  3.0
# 1        639.0     243.0   2891.000000              ...                  8.0
# 2          9.0       4.0     93.154812              ...                  2.0
# 3         18.0      21.0    186.507593              ...                  0.0
# 4         45.0      29.0    340.831981              ...                  6.0
# 5         39.0      18.0    235.109005              ...                  5.0
# 7         48.0      31.0    414.467066              ...                  0.0
# 8         32.0      13.0    204.000000              ...                  6.0
# 10       133.0      79.0   1036.386176              ...                  6.0
# 11      1197.0     466.0   6534.089505              ...                  0.0
# 12      1109.0     468.0   4941.985565              ...                  4.0
# 13        79.0     106.0    321.681732              ...                  4.0
# 14       136.0     144.0   1354.000000              ...                  3.0
# 15      1459.0     488.0   7971.178287              ...                  2.0
# 16      2606.0     764.0  10978.043086              ...                  6.0
# 17       110.0      56.0    816.553817              ...                  3.0
# 18       467.0     294.0   3536.000000              ...                  0.0
# 19        11.0       4.0     52.000000              ...                  4.0
# 20       368.0     172.0   2115.000000              ...                  2.0
# 21      3282.0     735.0  10605.075410              ...                  5.0
# 22      4542.0    1251.0  16644.256939              ...                  2.0
# 23        75.0      43.0    651.533503              ...                  3.0
# 24       880.0     353.0   5746.105302              ...                 11.0
# 25       112.0     186.0   1523.000000              ...                  0.0
# 26      4156.0    1610.0  20356.560378              ...                  9.0
# 27        32.0      27.0    329.221992              ...                  1.0
# 28       115.0     156.0    844.013989              ...                  3.0
# 29        16.0       2.0    127.611650              ...                  3.0
# 30       974.0     258.0   3314.844088              ...                  3.0
# 31       415.0     177.0   2502.000000              ...                  4.0
# ...        ...       ...           ...              ...                  ...
# 1268     456.0     203.0   3324.428701              ...                  1.0
# 1269      20.0       5.0    146.017355              ...                  5.0
# 1270       7.0       6.0     52.985075              ...                  7.0
# 1271      29.0      17.0    219.541139              ...                  2.0
# 1273     667.0     175.0   2869.034916              ...                  0.0
# 1274    1763.0     866.0  13128.982703              ...                  2.0
# 1275    2078.0     758.0   9110.053737              ...                  1.0
# 1276     609.0     229.0   2758.000000              ...                  2.0
# 1277    3986.0    1260.0  17925.589606              ...                  8.0
# 1278    1165.0     202.0   3965.918287              ...                  0.0
# 1279    3934.0    1283.0  21081.071650              ...                  7.0
# 1280    1534.0     508.0   8110.306181              ...                  1.0
# 1281    2652.0     835.0   9120.094870              ...                  9.0
# 1282     319.0      80.0   1381.270668              ...                  0.0
# 1283    2831.0    1036.0  14077.028363              ...                  2.0
# 1284    1645.0    1096.0   9789.753297              ...                  7.0
# 1285      49.0      19.0    240.730964              ...                  9.0
# 1286      31.0      22.0    265.530935              ...                  4.0
# 1287      27.0       5.0    107.641745              ...                  5.0
# 1288      29.0       1.0    192.308244              ...                  5.0
# 1289      21.0      12.0    175.000000              ...                  1.0
# 1291    1912.0     792.0  10279.879883              ...                  5.0
# 1292      72.0     133.0    320.224688              ...                  3.0
# 1293     172.0      40.0    946.000000              ...                  6.0
# 1294      33.0      25.0    368.000000              ...                 10.0
# 1295    2111.0     753.0  10363.061937              ...                  3.0
# 1296     910.0     551.0   6033.502470              ...                  3.0
# 1297      14.0       3.0     70.000000              ...                  5.0
# 1298      17.0       5.0    109.978022              ...                  5.0
# 1299      44.0       9.0    289.000000              ...                  2.0
#
#       ETBE15  ETFZ15  ETGU15  ETGZ15  ETOQ15  ETTEF115  ETTEFP1015  \
# 0       38.0   142.0  1078.0   225.0   214.0     335.0        67.0
# 1       47.0   135.0   623.0   241.0    65.0     228.0        72.0
# 2        0.0     2.0     5.0     2.0     4.0       4.0         0.0
# 3        6.0     6.0    48.0    17.0    14.0      13.0         4.0
# 4        3.0     8.0    53.0    12.0     5.0      14.0         2.0
# 5        4.0     7.0    40.0    10.0     8.0      20.0         0.0
# 7        3.0    13.0    65.0    20.0     5.0      19.0         2.0
# 8        3.0     4.0    27.0     3.0     5.0      12.0         0.0
# 10      14.0    31.0   129.0    23.0    25.0      36.0         7.0
# 11      29.0    92.0  1107.0   176.0   213.0     223.0        69.0
# 12      44.0   230.0   758.0   224.0   122.0     325.0        40.0
# 13       4.0    10.0    45.0     7.0    14.0      19.0         5.0
# 14      23.0    44.0   325.0    81.0    32.0      92.0        36.0
# 15      61.0   271.0   961.0   246.0   162.0     364.0        63.0
# 16      83.0   375.0  1590.0   437.0   185.0     472.0       170.0
# 17      10.0    14.0    88.0    14.0    13.0      19.0         2.0
# 18      41.0   113.0   547.0   123.0    85.0     238.0        56.0
# 19       0.0     2.0     7.0     0.0     1.0       3.0         0.0
# 20      25.0    71.0   223.0    76.0    53.0      71.0        32.0
# 21      93.0   264.0  1365.0   460.0   256.0     489.0       142.0
# 22      83.0   334.0  2173.0   672.0   505.0     760.0       181.0
# 23       6.0    12.0    98.0    17.0    16.0      34.0         3.0
# 24      31.0   165.0   992.0   239.0   181.0     314.0        85.0
# 25       7.0    10.0   172.0    24.0    33.0      20.0         7.0
# 26     167.0   568.0  2487.0   661.0   502.0     797.0       225.0
# 27       2.0     6.0    57.0    14.0    15.0      10.0         4.0
# 28       7.0    20.0   160.0    44.0    43.0      61.0        19.0
# 29       1.0     3.0    23.0     1.0     5.0       7.0         0.0
# 30      35.0    84.0   389.0   125.0    74.0     101.0        56.0
# 31      34.0    77.0   398.0   151.0    56.0     145.0        56.0
# ...      ...     ...     ...     ...     ...       ...         ...
# 1268    79.0    78.0   600.0   161.0   101.0     199.0       129.0
# 1269     0.0     9.0    37.0     6.0     4.0      16.0         2.0
# 1270     2.0     0.0    10.0     1.0     3.0       4.0         0.0
# 1271     2.0     2.0    30.0     2.0     8.0       4.0         2.0
# 1273    22.0    56.0   509.0   167.0    39.0     142.0        25.0
# 1274    64.0   156.0  1840.0   256.0   354.0     405.0       102.0
# 1275    63.0   415.0  1445.0   455.0   213.0     508.0        95.0
# 1276    25.0    92.0   320.0    95.0    68.0     150.0        29.0
# 1277   114.0   501.0  2544.0   763.0   363.0     819.0       257.0
# 1278    14.0    45.0   316.0    95.0    62.0      82.0        27.0
# 1279   147.0   326.0  4204.0   636.0   617.0    1086.0       371.0
# 1280    65.0   222.0  1375.0   250.0   156.0     310.0        46.0
# 1281    66.0   299.0  1369.0   462.0   175.0     523.0       210.0
# 1282    10.0    25.0   128.0    37.0    27.0      36.0        16.0
# 1283    67.0   192.0  1508.0   432.0   283.0     501.0        85.0
# 1284    54.0   209.0  1290.0   274.0   301.0     425.0        82.0
# 1285     1.0     4.0    18.0     4.0     6.0      12.0         1.0
# 1286     6.0     7.0    52.0     8.0     3.0      14.0         2.0
# 1287     2.0     5.0    33.0     5.0     3.0      11.0         4.0
# 1288     2.0     8.0    36.0     8.0     7.0      13.0         0.0
# 1289     0.0     4.0    23.0     3.0     3.0       5.0         0.0
# 1291    90.0   209.0  1269.0   347.0   267.0     383.0       135.0
# 1292     3.0     9.0    32.0    12.0     5.0       6.0         3.0
# 1293     5.0    11.0   111.0    18.0    13.0      25.0        15.0
# 1294     5.0    15.0    36.0    11.0     8.0      13.0         0.0
# 1295    60.0   273.0  1365.0   297.0   247.0     419.0        86.0
# 1296    71.0   199.0   876.0   177.0   247.0     301.0        45.0
# 1297     3.0     6.0     9.0     3.0     2.0       9.0         0.0
# 1298     1.0     1.0    31.0    10.0     3.0      10.0         2.0
# 1299     6.0     7.0    56.0    13.0     6.0      14.0        18.0
#
#                                               Geo Shape  \
# 0     {"type": "Polygon", "coordinates": [[[2.274621...
# 1     {"type": "Polygon", "coordinates": [[[2.193617...
# 2     {"type": "Polygon", "coordinates": [[[1.732068...
# 3     {"type": "Polygon", "coordinates": [[[1.623323...
# 4     {"type": "Polygon", "coordinates": [[[2.236020...
# 5     {"type": "Polygon", "coordinates": [[[2.091848...
# 7     {"type": "Polygon", "coordinates": [[[2.396040...
# 8     {"type": "Polygon", "coordinates": [[[1.706332...
# 10    {"type": "Polygon", "coordinates": [[[2.338576...
# 11    {"type": "Polygon", "coordinates": [[[2.454649...
# 12    {"type": "Polygon", "coordinates": [[[2.416533...
# 13    {"type": "Polygon", "coordinates": [[[1.662678...
# 14    {"type": "Polygon", "coordinates": [[[2.594673...
# 15    {"type": "Polygon", "coordinates": [[[2.557404...
# 16    {"type": "Polygon", "coordinates": [[[2.206095...
# 17    {"type": "Polygon", "coordinates": [[[2.193140...
# 18    {"type": "Polygon", "coordinates": [[[2.183163...
# 19    {"type": "Polygon", "coordinates": [[[1.836029...
# 20    {"type": "Polygon", "coordinates": [[[1.644697...
# 21    {"type": "Polygon", "coordinates": [[[1.881041...
# 22    {"type": "Polygon", "coordinates": [[[1.708398...
# 23    {"type": "Polygon", "coordinates": [[[1.874668...
# 24    {"type": "Polygon", "coordinates": [[[2.120244...
# 25    {"type": "Polygon", "coordinates": [[[2.089121...
# 26    {"type": "Polygon", "coordinates": [[[2.173144...
# 27    {"type": "Polygon", "coordinates": [[[1.952895...
# 28    {"type": "Polygon", "coordinates": [[[1.767947...
# 29    {"type": "Polygon", "coordinates": [[[1.689777...
# 30    {"type": "Polygon", "coordinates": [[[2.024724...
# 31    {"type": "Polygon", "coordinates": [[[1.806859...
# ...                                                 ...
# 1268  {"type": "Polygon", "coordinates": [[[2.398566...
# 1269  {"type": "Polygon", "coordinates": [[[2.034184...
# 1270  {"type": "Polygon", "coordinates": [[[2.276634...
# 1271  {"type": "Polygon", "coordinates": [[[2.037636...
# 1273  {"type": "Polygon", "coordinates": [[[2.311668...
# 1274  {"type": "Polygon", "coordinates": [[[2.278183...
# 1275  {"type": "Polygon", "coordinates": [[[2.510918...
# 1276  {"type": "Polygon", "coordinates": [[[2.557042...
# 1277  {"type": "Polygon", "coordinates": [[[2.481538...
# 1278  {"type": "Polygon", "coordinates": [[[2.404448...
# 1279  {"type": "Polygon", "coordinates": [[[2.223615...
# 1280  {"type": "Polygon", "coordinates": [[[2.410690...
# 1281  {"type": "Polygon", "coordinates": [[[2.485755...
# 1282  {"type": "Polygon", "coordinates": [[[2.321772...
# 1283  {"type": "Polygon", "coordinates": [[[2.217132...
# 1284  {"type": "Polygon", "coordinates": [[[2.290334...
# 1285  {"type": "Polygon", "coordinates": [[[1.676493...
# 1286  {"type": "Polygon", "coordinates": [[[2.030079...
# 1287  {"type": "Polygon", "coordinates": [[[2.526069...
# 1288  {"type": "Polygon", "coordinates": [[[2.000266...
# 1289  {"type": "Polygon", "coordinates": [[[1.840644...
# 1291  {"type": "Polygon", "coordinates": [[[2.183163...
# 1292  {"type": "Polygon", "coordinates": [[[1.671819...
# 1293  {"type": "Polygon", "coordinates": [[[2.545733...
# 1294  {"type": "Polygon", "coordinates": [[[1.722195...
# 1295  {"type": "Polygon", "coordinates": [[[2.274621...
# 1296  {"type": "Polygon", "coordinates": [[[2.253146...
# 1297  {"type": "Polygon", "coordinates": [[[2.370400...
# 1298  {"type": "Polygon", "coordinates": [[[1.904456...
# 1299  {"type": "Polygon", "coordinates": [[[2.545733...
#
#                       geo_point_2d
# 0     48.9695044801, 2.28470111182
# 1      49.0190794714, 2.1606870483
# 2      49.058878265, 1.74176317637
# 3     49.0883415268, 1.63442788467
# 4     49.0697597649, 2.23847351378
# 5     49.1336202497, 2.10424995109
# 7     49.1229725942, 2.39417999384
# 8     49.0861330336, 1.73009571144
# 10    49.1407826035, 2.37895297389
# 11    48.8182517632, 2.43673908533
# 12    48.9859786056, 2.41754697068
# 13    49.1424195814, 1.66498224327
# 14     48.735407513, 2.57657899871
# 15    48.8062253343, 2.57508931375
# 16    48.9262855146, 2.21169941046
# 17    49.0838595541, 2.19153531919
# 18    49.0150594532, 2.19244222257
# 19    49.1255342848, 1.81439905662
# 20    48.9967325176, 1.60741730831
# 21    48.9890049642, 1.91405725676
# 22    48.9983739633, 1.69410227782
# 23     48.888885919, 1.87473177505
# 24    48.9172863598, 2.13951942247
# 25    48.8327488759, 2.10529778914
# 26    48.9396530917, 2.17437718087
# 27    48.5361963039, 1.94118647085
# 28    48.8025195338, 1.76850175626
# 29    48.8777686667, 1.71941826646
# 30    48.9762996047, 2.03110014581
# 31    48.9479265922, 1.81350083131
# ...                            ...
# 1268  48.6141589308, 2.38020972375
# 1269  48.4557682089, 2.05140502516
# 1270  48.3267276835, 2.28985718932
# 1271  48.6754863286, 2.04911269659
# 1273  48.9373520184, 2.32651350169
# 1274  48.8215811431, 2.28726066649
# 1275  48.9077497585, 2.50323627608
# 1276  48.9325361418, 2.58245041554
# 1277  48.8745436228, 2.48657191745
# 1278  48.9511913333, 2.42389861364
# 1279  48.8699520558, 2.21968010803
# 1280  48.8852204631, 2.40598240359
# 1281  48.9862889229, 2.45676363518
# 1282   49.1607288872, 2.3297519091
# 1283    48.98847653, 2.22476084321
# 1284  48.9907177266, 2.27755595285
# 1285  49.1135025608, 1.70344103634
# 1286   49.132843947, 2.04818002416
# 1287  49.0421020906, 2.54574562124
# 1288  49.1231410607, 1.99306520618
# 1289  49.0662063375, 1.87000635381
# 1291    49.02679389, 2.22190959326
# 1292  49.2133199192, 1.70355286567
# 1293  49.0625792814, 2.56710269469
# 1294  49.1670219783, 1.76147057245
# 1295   48.971575438, 2.25336384763
# 1296  49.0187947257, 2.24666220276
# 1297  49.0745767074, 2.38634517834
# 1298  49.0908194723, 1.90500672567
# 1299  49.0606938423, 2.53436931299
#
# [1277 rows x 36 columns]

# %% [markdown]
# ## Validation du modèle et choix du nombre de classes
# Dans le cas du clustering, il est très difficile de valider le modèle avec des indicateurs
# statistiques. En effet, on ne peut pas tester la qualité prédictive. Nous allons
# essayer de faire en sorte d’obtenir des classes les plus homogènes possibles et de
# minimiser l’inertie.
#
# Afin de choisir le nombre de classe à utiliser on peut utiliser un
# graphique. Elle représente l’inertie par nombre de classes. On recherche un coude
# dans cette courbe pour décider le nombre à retenir.

# %%
from sklearn.cluster import KMeans,AgglomerativeClustering
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# on crée une liste dans laquelle on stocke les inerties
inerties=[]
# on fait une boucle de 2 à 9 pour tester toutes ces possibiliéts
for k in range(2, 10):
    # pour chaque k, on crée un modèle et on l’ajuste
    kmeans=KMeans(n_clusters=k)
    kmeans.fit(x)
    # on stocke l’inertie associée
    inerties.append(kmeans.inertia_)

# %%
# on représente le graphique
fig=plt.figure(figsize=(6, 4))
plt.plot(range(2, 10), inerties)
plt.xlabel("Nombre de clusters")
plt.ylabel("Inertie")
plt.title('Inertie vs nombre de classes')
#plt.savefig("./images/elbow.png")
# Out:
# Text(0.5,1,'Inertie vs nombre de classes')

# %% [markdown]
# ![image](./images/elbow.png)

# %% [markdown]
# ## Application des k-means
# Pour appliquer les k-means sur nos données, on utilisera :

# %%
from sklearn.cluster import KMeans
modele_km=KMeans(n_clusters=4)
modele_km.fit(x)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#     n_clusters=4, n_init=10, n_jobs=None, precompute_distances='auto',
#     random_state=None, tol=0.0001, verbose=0)

# %%
from sklearn.cluster import AgglomerativeClustering
modele_cah=AgglomerativeClustering(n_clusters=4)
modele_cah.fit(x)
# Out:
# AgglomerativeClustering(affinity='euclidean', compute_full_tree='auto',
#             connectivity=None, linkage='ward', memory=None, n_clusters=4,
#             pooling_func='deprecated')

# %%
# on stocke les classes d’appartenance dans classes_km
classes_km = modele_km.labels_
classes_cah = modele_cah.labels_
# on crée un DataFrame avec le nombre d’individus par classe
count=pd.DataFrame(np.unique(classes_km,return_counts=True)[1],
columns=["Nombre d’individus"])
# on stocke les centres des classes dans un DataFrame
centres=pd.DataFrame(modele_km.cluster_centers_,columns=x.columns)
# on affiche le DataFrame avec les deux informations
pd.set_option('precision',2)
print(pd.concat([count,pd.DataFrame(centres,columns=x.columns)],axis=1).T)
pd.reset_option('precision')
# Out:
#                            0          1         2         3
# Nombre d’individus   1063.00      10.00    172.00     32.00
# P14_POP              2520.14  177206.80  30048.72  75067.59
# P09_POP              2438.52  177166.40  29077.12  73660.69
# SUPERF                  9.48       8.21      8.59      8.29
# NAIS0914              157.02   12244.80   2467.56   6120.00
# DECE0914               77.66    5637.90    872.23   2127.72
# P14_MEN               971.20   90563.71  12136.82  32671.56
# NAISD16                30.86    2333.60    486.42   1192.66
# DECESD16               17.10    1147.60    181.58    428.94
# P14_LOG              1065.33  104668.51  13126.00  36851.11
# P14_RP                971.20   90563.71  12136.82  32671.56
# P14_RSECOCC            30.34    6173.12    232.42   1688.96
# P14_LOGVAC             63.78    7931.68    756.76   2490.60
# P14_RP_PROP           669.37   29323.08   5693.89  13125.46
# NBMENFISC14           958.26   82067.90  11736.59  30785.59
# MED14               25363.69   26142.57  22238.60  25189.03
# P14_EMPLT             756.00  107240.28  12154.64  53519.14
# P14_EMPLT_SAL         662.39   92635.95  11006.97  48372.26
# P09_EMPLT             732.02  108029.47  12126.41  53240.56
# P14_POP1564          1641.37  123403.33  19756.05  50433.32
# P14_CHOM1564          124.05   11852.98   2034.11   5228.42
# P14_ACT1564          1253.88   95412.51  14934.71  38380.76
# ETTOT15               208.70   31466.20   2707.62  12275.59
# ETAZ15                  5.23      27.80      4.63     14.66
# ETBE15                  9.37     797.40     95.80    358.25
# ETFZ15                 25.19    1513.10    285.85    833.16
# ETGU15                141.75   25662.30   1996.67   9936.03
# ETGZ15                 35.38    3482.30    462.74   1590.19
# ETOQ15                 27.15    3465.60    324.67   1133.50
# ETTEF115               45.59    6722.00    604.03   2785.53
# ETTEFP1015             12.71    1217.90    166.35    731.22

# %%
# on crée une figure
plt.figure(figsize=(10,8))
# on fait une boucle sur les classes en définissant des marqueurs par classe
markers=["+","s","^","v"]
for val, mark in zip(np.unique(classes_km),markers):
    plt.scatter(position["latitude"][classes_km==val],
                position["longitude"][classes_km==val], marker=mark,
                label="classe% i"%(val))
plt.title("Représentation des classes sur la région Ile-de-France")
plt.legend()
#plt.savefig("./images/idf2.png")

# %%
# on crée une figure
plt.figure(figsize=(10,8))
# on fait une boucle sur les classes en définissant des marqueurs par classe
markers=["+","s","^","v"]
for val, mark in zip(np.unique(classes_cah),markers):
    plt.scatter(position["latitude"][classes_cah==val],
                position["longitude"][classes_cah==val], marker=mark,
                label="classe% i"%(val))
plt.title("Représentation des classes sur la région Ile-de-France")
plt.legend()
#plt.savefig("./images/idf2.png")

# %%
pd.crosstab(classes_cah,classes_km)
# Out:
# col_0     0   1    2   3
# row_0
# 0        51   0  171   7
# 1         0   0    1  25
# 2      1012   0    0   0
# 3         0  10    0   0

# %% [markdown]
# ![image](./images/idf2.png)

# %% [markdown]
# On voit que les quatre classes se répartissent très bien sur l’Ile-de-France avec :
# - Classe 0 : petites communes éloignées de Paris
# - Classe 1 : grandes communes de la petite ceinture
# - Classe 2 : arrondissements extérieurs de Paris (12 à 20)
# - Classe 3 : communes moyennes moins proches de Paris
#
# On pourrait bien entendu ajouter un fond de carte comme nous l’avons fait dans
# le chapitre 5.

# %% [markdown]
# **Exercice :**
#
# Traitement d'image avec les Kmeans
#
# On veut changer le nombre de couleur d'une photo de New York avec les K-means

# %% [markdown]
# ## Les méthodes de réduction de dimension
#
# Parmi les algorithmes non supervisés, on inclut souvent des méthodes qui permettent de réduire le nombre de dimensions de vos données. Nous allons présenter
# l’utilisation de trois d’entre elles : l’analyse en composantes principales et deux
# méthodes non linéaires.
#
# Les méthodes de réduction de dimensions se divisent en deux familles : les
# méthodes linéaires et les méthodes non linéaires.

# %% [markdown]
# ### Méthodes linéaires
# Il s’agit de méthodes d’analyse de données souvent bien connues. On pourra citer :
#
# - l’analyse en composantes principales (ACP/PCA)
# - l’analyse en composantes indépendantes
# - la décomposition en valeurs singulières
# - l’analyse factorielle
# - les analyses multi-tableaux
#
# Et pour des données qualitatives :
#
# - l’analyse des correspondances multiples
#
# Scikit-Learn possède de nombreuses approches mais nous allons nous concentrer sur une application de l’analyse en composantes principales.

# %% [markdown]
# ## Application de l'ACP
# Nous utilisons une base de données d’images : celle du jeu de données Fashion-
# MNIST qui rassemble des photographies de vêtements (un vêtement par image).
# Ces données sont directement disponibles dans le package Keras. Nous allons utiliser l’ACP pour réduire la complexité de ces images.
#
# Une description des données est disponible au début du chapitre 4.

# %%
# %matplotlib inline
from sklearn.decomposition import PCA
import numpy as np
import matplotlib.pyplot as plt
from keras.datasets import fashion_mnist
# Out:
# C:\Users\s4d-asus-14\Anaconda3\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
# on récupère les données dans 4 arrays
(train_img, train_lbl), (test_img, test_lbl)=fashion_mnist.load_data()
# ce jeu de données d’apprentissage est composé de 600000 images
# ayant 28 x 28 pixels en noir et blanc
train_img.shape
# Out:
# (60000, 28, 28)

# %%
# l’image 801 a le label 9: chaussure
train_lbl[300]
# Out:
# 5

# %%
plt.imshow(train_img[700])

# %% [markdown]
# Nous avons donc récupéré des images de taille 28 par 28 qui sont stockées dans
# un array avec une image par ligne.
#
# L’objectif est de réduire le nombre d’informations nécessaires à l’apprentissage de ces images en vue d’appliquer un modèle prédictif. Nous allons voir comment simplifier ces images en utilisant toutes les données :

# %%
# on passe les images en deux dimensions
img_acp=train_img.reshape(train_img.shape[0],-1)

# on crée un modèle d’ACP
pca=PCA(n_components=.90)

# on réduit le nombre de dimensions avec l’ACP
donnees_reduites=pca.fit_transform(img_acp)

donnees_reduites.shape
# Out:
# (60000, 84)

# %%
# Pour capturer 80% de l’information, on utiliser 43 des 784 composantes
# on projette les données réduites dans l’espace d’origine
projection=pca.inverse_transform(donnees_reduites)

# %%
projection.shape
# Out:
# (60000, 784)

# %%
# on affiche les résultats
plt.figure(figsize=(8,4));
# image initale
plt.subplot(1, 2, 1);
plt.imshow(img_acp[455].reshape(28,28))
plt.xlabel('%i composantes'%(img_acp.shape[1]))
plt.title('Image initiale');
# image basée sur l’ACP
plt.subplot(1, 2, 2);
plt.imshow(projection[455].reshape(28, 28))
plt.xlabel('%i composantes' %(donnees_reduites.shape[1]))
plt.title('%s de variance expliquée'%(str(pca.n_components*100)+"%"))
plt.savefig("transfo.png")

# %% [markdown]
# ## Aller plus loin
#
# De nombreuses autres méthodes de machine learning non supervisé sont disponibles. La documentation de scikit-learn vous aidera à en avoir un aperçu très lare :
#
# - Clustering :
#
# http://scikit-learn.org/stable/modules/clustering.html#clustering
#
#
# - Réduction de dimension :
#
# http://scikit-learn.org/stable/modules/decomposition.html#decompositions
